# %%
import csv
import sklearn
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %%
def load_dataset():
    csv_df = pd.read_csv("boston.csv")
    return csv_df
boston_dataframe = load_dataset()

# %%
def print_summarize_dataset(dataset): 
    
    print("Dataset dimension:")
    print(dataset.shape)
    print("First 10 rows of dataset:")
    print(dataset.head(10))
    print("Statistical summary:")
    print(dataset.describe())
    
    
#     print(f"Dataset dimension:\n{boston_dataframe.shape}\n\nFirst 10 rows of dataset:\n{boston_dataframe.head(10)}\n\nStatistical summary:\n{boston_dataframe.describe()}") 

# print_summarize_dataset(boston_dataframe)

# %%
def clean_dataset(boston_dataframe):
#     nan_d = data.isnull().sum()
    return boston_dataframe.dropna()

# clean_dataset(boston_dataframe)

# %%
def print_histograms(boston_dataframe):
    for (col_name, col_value) in boston_dataframe.iteritems():
        plt.hist(col_value)
        plt.title(col_name)
        plt.show()
    
# print_histograms(boston_dataframe)

# %%
def compute_correlations_matrix(boston_dataframe):
#      return sns.heatmap(boston_dataframe.corr(), annot=True, cmap="coolwarm")
    return boston_dataframe.corr()

correlations = compute_correlations_matrix(boston_dataframe)
# correlations['MDEV']

# %%
def print_scatter_matrix(boston_dataframe):
    
#     boston_dataframe.plot(x="CRIM", y="MDEV", kind="scatter", title="CRIM")
#     boston_dataframe.plot(x="ZN", y="MDEV", kind="scatter", title="ZN")
#     boston_dataframe.plot(x="INDUS", y="MDEV", kind="scatter", title="INDUS")
#     boston_dataframe.plot(x="CHAS", y="MDEV", kind="scatter", title="CHAS")
#     boston_dataframe.plot(x="NOX", y="MDEV", kind="scatter", title="NOX")
#     boston_dataframe.plot(x="RM", y="MDEV", kind="scatter", title="RM")
#     boston_dataframe.plot(x="AGE", y="MDEV", kind="scatter", title="AGE")
#     boston_dataframe.plot(x="DIS", y="MDEV", kind="scatter", title="DIS")
#     boston_dataframe.plot(x="RAD", y="MDEV", kind="scatter", title="RAD")
#     boston_dataframe.plot(x="TAX", y="MDEV", kind="scatter", title="TAX")
#     boston_dataframe.plot(x="PTRATIO", y="MDEV", kind="scatter", title="PTRATIO")
#     boston_dataframe.plot(x="B", y="MDEV", kind="scatter", title="B")
#     boston_dataframe.plot(x="LSTAT", y="MDEV", kind="scatter", title="LSTAT")
    pd.plotting.scatter_matrix(boston_dataframe,figsize=(12,12))
    plt.show()
    
    

# print_scatter_matrix(boston_dataframe)

# %%
def boston_fit_model(dataset):
    # SELECT two columns from our 
    model_dataset = dataset[["RM","MDEV"]]
    regressor = sklearn.linear_model.LinearRegression()
    # Extract column 1
    x = model_dataset.iloc[:, :-1].values
    # Extract column 2
    y = model_dataset.iloc[:, 1].values
    # Train the model
    x_training, x_testing, y_training , y_testing = train_test_split(x, y, test_size=0.2, random_state = 0)
    regressor.fit(x_training, y_training)
    return regressor

# boston_fit_model(boston_dataframe)

# %%
def boston_predict(estimator, array_to_predict):
    return estimator.predict(array_to_predict)

m=boston_dataframe[["RM","MDEV"]]
x = model_dataset.iloc[:, :-1].values
estimator = boston_fit_model(boston_dataframe)
predict_res = boston_predict(estimator,x)

# %%
def print_model_prediction_evaluator(base_test, prediction):
    print('Mean Absolute Error:', metrics.mean_absolute_error(base_test, prediction))
    print('Mean Squared Error:', metrics.mean_squared_error(base_test, prediction))
    print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(base_test, prediction)))
    
model_dataset = boston_dataframe[["RM","MDEV"]]
y = model_dataset.iloc[:, 1].values
print_model_prediction_evaluator(predict_res, y)
# Out:
# Mean Absolute Error: 4.444571877734202
# Mean Squared Error: 43.64431493765264
# Root Mean Squared Error: 6.60638440734814

# %%
# !gandalf
# Out:
#  ██████╗ ██╗    ██╗ █████╗ ███████╗ █████╗ ██████╗    ██╗ ██████╗
# ██╔═══██╗██║    ██║██╔══██╗██╔════╝██╔══██╗██╔══██╗   ██║██╔═══██╗
# ██║   ██║██║ █╗ ██║███████║███████╗███████║██████╔╝   ██║██║   ██║
# ██║▄▄ ██║██║███╗██║██╔══██║╚════██║██╔══██║██╔══██╗   ██║██║   ██║
# ╚██████╔╝╚███╔███╔╝██║  ██║███████║██║  ██║██║  ██║██╗██║╚██████╔╝
#  ╚══▀▀═╝  ╚══╝╚══╝ ╚═╝  ╚═╝╚══════╝╚═╝  ╚═╝╚═╝  ╚═╝╚═╝╚═╝ ╚═════╝
#
# Booting Gandalf v4.1.12-deab022 (production)
# Loading parameters:  OK
# User tolbayev_m connection: OK
#
#
# <MY_TU_VERRAS>
# Directory . exists: OK
# Pushing exercise: OK
# Printing your report:
#
#       REPORT         MY TU VERRAS
#
#  Status             SUCCESS
#  Execution Runtime  9.181229
#  Score              [=======-] 7/8
#
#
# Checks detail Report:
#
#  TEST BOSTON FIT MODEL  SUCCESS
#
#
#
#  TEST BOSTON PREDICT  SUCCESS
#
#
#
#  TEST CLEAN DATASET  SUCCESS
#
#
#
#  TEST COMPUTE CORRELATIONS MATRIX  SUCCESS
#
#
#
#  TEST LOAD DATASET  SUCCESS
#
#
#
# ...
